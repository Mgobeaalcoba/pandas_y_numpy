# %%
import pandas as pd
import numpy as np

# %%
path = '/content/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv'
df = pd.read_csv(path)
df.sample(3)
# Out:
#                                                   Name              Author  \
# 118  Game of Thrones Boxed Set: A Game of Thrones/A...  George R.R. Martin
# 531  Wheat Belly: Lose the Wheat, Lose the Weight, ...       William Davis
# 89   Dover Creative Haven Art Nouveau Animal Design...         Marty Noble
#
#      User Rating  Reviews  Price  Year        Genre
# 118          4.6     5594      5  2011      Fiction
# 531          4.4     7497      6  2012  Non Fiction
# 89           4.6     2134      5  2015  Non Fiction

# %% [markdown]
# # pivot_table y melt, dos funciones que sirven para cambiar la estructura de nuestro DataFrame de acuerdo a nuestras necesidades.

# %%
# Pivot table: Pivot, básicamente, transforma los valores de determinadas columnas o filas en los índices de un nuevo DataFrame, y la intersección de estos es el valor resultante.

df.pivot_table(index='Author',columns='Genre',values='User Rating') # Junto con group by son dos formas de hacer TD´s. En este caso especifico todo, filas
# coumnas y valores en la declaración de la función.
# Out:
# Genre                       Fiction  Non Fiction
# Author
# Abraham Verghese                4.6          NaN
# Adam Gasiewski                  NaN     4.400000
# Adam Mansbach                   4.8          NaN
# Adir Levy                       4.8          NaN
# Admiral William H. McRaven      NaN     4.700000
# ...                             ...          ...
# Walter Isaacson                 NaN     4.566667
# William Davis                   NaN     4.400000
# William P. Young                4.6          NaN
# Wizards RPG Team                4.8          NaN
# Zhi Gang Sha                    NaN     4.600000
#
# [248 rows x 2 columns]

# %%
df.pivot_table(index='Genre',columns='Year', values='User Rating',aggfunc='sum') # Puedo especificar tmb que función de agregación usar.
# Out:
# Year          2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# Genre
# Fiction      110.2   92.3   97.0   94.4  109.1  134.3   79.1   89.6  113.7
# Non Fiction  119.0  135.6  130.9  132.2  118.6   96.8  153.3  144.3  119.3
#
# Year          2018   2019
# Genre
# Fiction       99.5   96.4
# Non Fiction  133.9  140.6

# %% [markdown]
# # Melt : El método melt toma las columnas del DataFrame y las pasa a filas, con dos nuevas columnas para especificar la antigua columna y el valor que traía.

# %%
df[['Name','Genre']].head(5)
# Out:
#                                                 Name        Genre
# 0                      10-Day Green Smoothie Cleanse  Non Fiction
# 1                                  11/22/63: A Novel      Fiction
# 2            12 Rules for Life: An Antidote to Chaos  Non Fiction
# 3                             1984 (Signet Classics)      Fiction
# 4  5,000 Awesome Facts (About Everything!) (Natio...  Non Fiction

# %%
df[['Name','Genre']].head(5).melt()
# Out:
#   variable                                              value
# 0     Name                      10-Day Green Smoothie Cleanse
# 1     Name                                  11/22/63: A Novel
# 2     Name            12 Rules for Life: An Antidote to Chaos
# 3     Name                             1984 (Signet Classics)
# 4     Name  5,000 Awesome Facts (About Everything!) (Natio...
# 5    Genre                                        Non Fiction
# 6    Genre                                            Fiction
# 7    Genre                                        Non Fiction
# 8    Genre                                            Fiction
# 9    Genre                                        Non Fiction

# %% [markdown]
# **Ahora cada resultado de las dos columnas pasa a una fila de este modo a tipo llave:valor.**

# %%
# Otro ejemplo de melt:
df.melt(id_vars='Year',value_vars='Genre')
# Out:
#      Year variable        value
# 0    2016    Genre  Non Fiction
# 1    2011    Genre      Fiction
# 2    2018    Genre  Non Fiction
# 3    2017    Genre      Fiction
# 4    2019    Genre  Non Fiction
# ..    ...      ...          ...
# 545  2019    Genre      Fiction
# 546  2016    Genre  Non Fiction
# 547  2017    Genre  Non Fiction
# 548  2018    Genre  Non Fiction
# 549  2019    Genre  Non Fiction
#
# [550 rows x 3 columns]

# %% [markdown]
# **Simplemente, podemos seleccionar las columnas que no quiero hacer melt usando el parámetro id_vars. Para este caso Year y también la única columna que quiero aplicar el melt, para este caso Genre con la propiedad value_vars.**
